# %% [markdown]
# # Database
#
# Import CSV file and build a SQLite database.
# Query database based on author's name.

# %%
import sqlite3
import os
import pandas as pd

csv_fname = 'db/HIV.csv'
table_name = os.path.basename(csv_fname).split('.')[0].lower()
db_fname = csv_fname.replace('.csv', '.db')

# %% [markdown]
# Build database

# %%
conn = sqlite3.connect(db_fname)
cursor = conn.cursor()

# %%
# drop any existing table
cursor.execute('DROP TABLE ' + table_name)

# ensure that first column is used as index;
# otherwise, another index column will be created
df = pd.read_csv(csv_fname, index_col=0)

# create sql table
df.to_sql(table_name, conn)

# %% [markdown]
# Query database

# %%
author_name = input('Author name: ')
query = 'SELECT pmid, ti from {0} where au like \'%{1}%\';'.format(table_name, author_name)

for row in cursor.execute(query):
    print(row)
# Out:
# Author name:  Lin
# (34797948, 'Size of HIV-1 reservoir is associated with telomere shortening and immunosenescence in early-treated European children with perinatally acquired HIV-1.')
# (34797882, 'Prevalence, beliefs and impact of drug-drug interactions between antiretroviral therapy and illicit drugs among people living with HIV in Spain.')
# (34797735, 'Ocular Syphilis: Experience over 11 Years at a German Ophthalmology Reference Centre.')
# (34797118, 'HIV stigma in Kenya: A family medicine led community orientated primary care approach.')
# (34794467, 'Predictors of the chest CT score in COVID-19 patients: a cross-sectional study.')
# (34793582, 'Localization of infection in neonatal rhesus macaques after oral viral challenge.')
# (34793251, 'Factors associated with normal or abnormal Papanicolaou smear among HIV-infected women at a national hospital in Lima, Peru, 2012-2015.')
# (34791318, 'Dexamethasone is a dose-dependent perpetrator of drug-drug interactions: implications for use in people living with HIV.')
# (34791296, 'Bone changes with candidate PrEP regimens containing tenofovir disoproxil fumarate and/or maraviroc and/or emtricitabine in US men and women: HPTN 069/ACTG A5305.')
# (34789509, 'Exploring the effectiveness of an online sexual health workshop on sexual and relationship beliefs and HIV/STI prevention knowledge among Singaporean youth.')
