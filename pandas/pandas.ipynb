# %%
import numpy as np
import pandas as pd

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8])
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates = pd.date_range("20210101", periods=10, freq='M')
dates
# Out:
# DatetimeIndex(['2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
df = pd.DataFrame(np.random.randn(10, 4), index=dates,
                  columns=list("ABCD"))
df
# Out:
#                    A         B         C         D
# 2021-01-31  0.333598 -0.558838 -0.881847 -0.882241
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127
# 2021-04-30  1.143933  2.295436 -0.847695 -0.019816
# 2021-05-31  0.671510 -2.379146 -0.310086 -0.109575
# 2021-06-30 -0.543429  0.926202  1.063359 -1.101633
# 2021-07-31  0.688580 -0.491351 -0.917668  0.159383
# 2021-08-31  2.076760 -1.336721  2.234340 -0.273113
# 2021-09-30 -0.832949  0.145391 -0.191181 -0.061820
# 2021-10-31 -1.256390 -0.200947 -0.641616  1.598169

# %%
df2 = pd.DataFrame(
    {
        "A": 1.0,
        "B": pd.Timestamp("20210101"),
        "C": pd.Series(1, index=list(range(4)), dtype="float32"),
        "D": np.array([3] * 4, dtype="int32"),
        "E": pd.Categorical(["test", "train", "test", "train"]),
        "F": "foo",
    }
)
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2021-01-01  1.0  3   test  foo
# 1  1.0 2021-01-01  1.0  3  train  foo
# 2  1.0 2021-01-01  1.0  3   test  foo
# 3  1.0 2021-01-01  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df2.A
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    1.0
# Name: A, dtype: float64

# %%
df.head()
# Out:
#                    A         B         C         D
# 2021-01-31  0.333598 -0.558838 -0.881847 -0.882241
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127
# 2021-04-30  1.143933  2.295436 -0.847695 -0.019816
# 2021-05-31  0.671510 -2.379146 -0.310086 -0.109575

# %%
df.tail(2)
# Out:
#                    A         B         C         D
# 2021-09-30 -0.832949  0.145391 -0.191181 -0.061820
# 2021-10-31 -1.256390 -0.200947 -0.641616  1.598169

# %%
df.index
# Out:
# DatetimeIndex(['2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
df.to_numpy()
# Out:
# array([[ 0.33359848, -0.55883813, -0.8818471 , -0.88224054],
#        [-1.57414692,  1.23699348,  0.341117  ,  1.53169998],
#        [ 0.24862279,  1.28087347, -0.60919769,  0.39512739],
#        [ 1.14393277,  2.29543574, -0.8476951 , -0.01981572],
#        [ 0.67150957, -2.37914641, -0.3100865 , -0.1095755 ],
#        [-0.54342918,  0.92620235,  1.0633591 , -1.10163344],
#        [ 0.68858024, -0.49135054, -0.91766837,  0.15938281],
#        [ 2.07675974, -1.33672124,  2.23434041, -0.27311302],
#        [-0.83294894,  0.1453908 , -0.19118053, -0.06181972],
#        [-1.25638994, -0.20094717, -0.64161611,  1.59816904]])

# %%
df.to_numpy().dtype
# Out:
# dtype('float64')

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2021-01-01 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2021-01-01 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2021-01-01 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2021-01-01 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
df.describe()
# Out:
#                A          B          C          D
# count  10.000000  10.000000  10.000000  10.000000
# mean    0.095609   0.091789  -0.076047   0.123618
# std     1.138900   1.385473   1.023903   0.882655
# min    -1.574147  -2.379146  -0.917668  -1.101633
# 25%    -0.760569  -0.541966  -0.796175  -0.232229
# 50%     0.291111  -0.027778  -0.459642  -0.040818
# 75%     0.684313   1.159296   0.208043   0.336191
# max     2.076760   2.295436   2.234340   1.598169

# %%
df.sort_index(axis=0, ascending=False)
# Out:
#                    A         B         C         D
# 2021-10-31 -1.256390 -0.200947 -0.641616  1.598169
# 2021-09-30 -0.832949  0.145391 -0.191181 -0.061820
# 2021-08-31  2.076760 -1.336721  2.234340 -0.273113
# 2021-07-31  0.688580 -0.491351 -0.917668  0.159383
# 2021-06-30 -0.543429  0.926202  1.063359 -1.101633
# 2021-05-31  0.671510 -2.379146 -0.310086 -0.109575
# 2021-04-30  1.143933  2.295436 -0.847695 -0.019816
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700
# 2021-01-31  0.333598 -0.558838 -0.881847 -0.882241

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2021-05-31  0.671510 -2.379146 -0.310086 -0.109575
# 2021-08-31  2.076760 -1.336721  2.234340 -0.273113
# 2021-01-31  0.333598 -0.558838 -0.881847 -0.882241
# 2021-07-31  0.688580 -0.491351 -0.917668  0.159383
# 2021-10-31 -1.256390 -0.200947 -0.641616  1.598169
# 2021-09-30 -0.832949  0.145391 -0.191181 -0.061820
# 2021-06-30 -0.543429  0.926202  1.063359 -1.101633
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127
# 2021-04-30  1.143933  2.295436 -0.847695 -0.019816

# %%
df[0:3]
# Out:
#                    A         B         C         D
# 2021-01-31  0.333598 -0.558838 -0.881847 -0.882241
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127

# %%
df['20210131':'20210430']
# Out:
#                    A         B         C         D
# 2021-01-31  0.333598 -0.558838 -0.881847 -0.882241
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127
# 2021-04-30  1.143933  2.295436 -0.847695 -0.019816

# %%
df.loc['2021-01-31']
# Out:
# A    0.333598
# B   -0.558838
# C   -0.881847
# D   -0.882241
# Name: 2021-01-31 00:00:00, dtype: float64

# %%
df.loc[dates[0]]
# Out:
# A    0.333598
# B   -0.558838
# C   -0.881847
# D   -0.882241
# Name: 2021-01-31 00:00:00, dtype: float64

# %%
df.loc[:, ['A', 'B']]
# Out:
#                    A         B
# 2021-01-31  0.333598 -0.558838
# 2021-02-28 -1.574147  1.236993
# 2021-03-31  0.248623  1.280873
# 2021-04-30  1.143933  2.295436
# 2021-05-31  0.671510 -2.379146
# 2021-06-30 -0.543429  0.926202
# 2021-07-31  0.688580 -0.491351
# 2021-08-31  2.076760 -1.336721
# 2021-09-30 -0.832949  0.145391
# 2021-10-31 -1.256390 -0.200947

# %%
df[['A', 'B']]
# Out:
#                    A         B
# 2021-01-31  0.333598 -0.558838
# 2021-02-28 -1.574147  1.236993
# 2021-03-31  0.248623  1.280873
# 2021-04-30  1.143933  2.295436
# 2021-05-31  0.671510 -2.379146
# 2021-06-30 -0.543429  0.926202
# 2021-07-31  0.688580 -0.491351
# 2021-08-31  2.076760 -1.336721
# 2021-09-30 -0.832949  0.145391
# 2021-10-31 -1.256390 -0.200947

# %%
df.loc[dates[0], ['A', 'B']]
# Out:
# A    0.333598
# B   -0.558838
# Name: 2021-01-31 00:00:00, dtype: float64

# %%
df.loc['20210831', 'A']
# Out:
# 2.0767597376724245

# %%
df.at[dates[7], 'A']
# Out:
# 2.0767597376724245

# %%
df.iloc[3]
# Out:
# A    1.143933
# B    2.295436
# C   -0.847695
# D   -0.019816
# Name: 2021-04-30 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2021-04-30  1.143933  2.295436
# 2021-05-31  0.671510 -2.379146

# %%
df.iloc[:, 3]
# Out:
# 2021-01-31   -0.882241
# 2021-02-28    1.531700
# 2021-03-31    0.395127
# 2021-04-30   -0.019816
# 2021-05-31   -0.109575
# 2021-06-30   -1.101633
# 2021-07-31    0.159383
# 2021-08-31   -0.273113
# 2021-09-30   -0.061820
# 2021-10-31    1.598169
# Freq: M, Name: D, dtype: float64

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127

# %%
df.iloc[1:3]
# Out:
#                    A         B         C         D
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127

# %%
df.iloc[1, 1]
# Out:
# 1.2369934760522783

# %%
df.iat[1, 1]
# Out:
# 1.2369934760522783

# %%
df[df.A > 0]
# Out:
#                    A         B         C         D
# 2021-01-31  0.333598 -0.558838 -0.881847 -0.882241
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127
# 2021-04-30  1.143933  2.295436 -0.847695 -0.019816
# 2021-05-31  0.671510 -2.379146 -0.310086 -0.109575
# 2021-07-31  0.688580 -0.491351 -0.917668  0.159383
# 2021-08-31  2.076760 -1.336721  2.234340 -0.273113

# %%
df[df.A < 0]
# Out:
#                    A         B         C         D
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700
# 2021-06-30 -0.543429  0.926202  1.063359 -1.101633
# 2021-09-30 -0.832949  0.145391 -0.191181 -0.061820
# 2021-10-31 -1.256390 -0.200947 -0.641616  1.598169

# %%
df2 = df.copy()
numbers = ['one', 'two', 'three', 'four', 'five',
           'six', 'seven', 'eight', 'nine', 'ten']
df2['E'] = [numbers[i-1] for i in [1, 1, 2, 3, 4, 5, 6, 6, 7, 7]]
df2
# Out:
#                    A         B         C         D      E
# 2021-01-31  0.333598 -0.558838 -0.881847 -0.882241    one
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700    one
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127    two
# 2021-04-30  1.143933  2.295436 -0.847695 -0.019816  three
# 2021-05-31  0.671510 -2.379146 -0.310086 -0.109575   four
# 2021-06-30 -0.543429  0.926202  1.063359 -1.101633   five
# 2021-07-31  0.688580 -0.491351 -0.917668  0.159383    six
# 2021-08-31  2.076760 -1.336721  2.234340 -0.273113    six
# 2021-09-30 -0.832949  0.145391 -0.191181 -0.061820  seven
# 2021-10-31 -1.256390 -0.200947 -0.641616  1.598169  seven

# %%
df2[df2.E.isin(['two', 'four'])]
# Out:
#                    A         B         C         D     E
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127   two
# 2021-05-31  0.671510 -2.379146 -0.310086 -0.109575  four

# %%
s1 = pd.Series(range(1, 1+10), index=reversed(dates))
s1
# Out:
# 2021-10-31     1
# 2021-09-30     2
# 2021-08-31     3
# 2021-07-31     4
# 2021-06-30     5
# 2021-05-31     6
# 2021-04-30     7
# 2021-03-31     8
# 2021-02-28     9
# 2021-01-31    10
# dtype: int64

# %%
df['F'] = s1
df
# Out:
#                    A         B         C         D   F
# 2021-01-31  0.333598 -0.558838 -0.881847 -0.882241  10
# 2021-02-28 -1.574147  1.236993  0.341117  1.531700   9
# 2021-03-31  0.248623  1.280873 -0.609198  0.395127   8
# 2021-04-30  1.143933  2.295436 -0.847695 -0.019816   7
# 2021-05-31  0.671510 -2.379146 -0.310086 -0.109575   6
# 2021-06-30 -0.543429  0.926202  1.063359 -1.101633   5
# 2021-07-31  0.688580 -0.491351 -0.917668  0.159383   4
# 2021-08-31  2.076760 -1.336721  2.234340 -0.273113   3
# 2021-09-30 -0.832949  0.145391 -0.191181 -0.061820   2
# 2021-10-31 -1.256390 -0.200947 -0.641616  1.598169   1

# %%
df.at[dates[0], 'A'] = -10
df
# Out:
#                     A         B         C         D   F
# 2021-01-31 -10.000000 -0.558838 -0.881847 -0.882241  10
# 2021-02-28  -1.574147  1.236993  0.341117  1.531700   9
# 2021-03-31   0.248623  1.280873 -0.609198  0.395127   8
# 2021-04-30   1.143933  2.295436 -0.847695 -0.019816   7
# 2021-05-31   0.671510 -2.379146 -0.310086 -0.109575   6
# 2021-06-30  -0.543429  0.926202  1.063359 -1.101633   5
# 2021-07-31   0.688580 -0.491351 -0.917668  0.159383   4
# 2021-08-31   2.076760 -1.336721  2.234340 -0.273113   3
# 2021-09-30  -0.832949  0.145391 -0.191181 -0.061820   2
# 2021-10-31  -1.256390 -0.200947 -0.641616  1.598169   1

# %%
df.iat[0, 1] = -5
df
# Out:
#                     A         B         C         D   F
# 2021-01-31 -10.000000 -5.000000 -0.881847 -0.882241  10
# 2021-02-28  -1.574147  1.236993  0.341117  1.531700   9
# 2021-03-31   0.248623  1.280873 -0.609198  0.395127   8
# 2021-04-30   1.143933  2.295436 -0.847695 -0.019816   7
# 2021-05-31   0.671510 -2.379146 -0.310086 -0.109575   6
# 2021-06-30  -0.543429  0.926202  1.063359 -1.101633   5
# 2021-07-31   0.688580 -0.491351 -0.917668  0.159383   4
# 2021-08-31   2.076760 -1.336721  2.234340 -0.273113   3
# 2021-09-30  -0.832949  0.145391 -0.191181 -0.061820   2
# 2021-10-31  -1.256390 -0.200947 -0.641616  1.598169   1

# %%
df.loc[:, 'D'] = np.array([5] * len(df))
df
# Out:
#                     A         B         C  D   F
# 2021-01-31 -10.000000 -5.000000 -0.881847  5  10
# 2021-02-28  -1.574147  1.236993  0.341117  5   9
# 2021-03-31   0.248623  1.280873 -0.609198  5   8
# 2021-04-30   1.143933  2.295436 -0.847695  5   7
# 2021-05-31   0.671510 -2.379146 -0.310086  5   6
# 2021-06-30  -0.543429  0.926202  1.063359  5   5
# 2021-07-31   0.688580 -0.491351 -0.917668  5   4
# 2021-08-31   2.076760 -1.336721  2.234340  5   3
# 2021-09-30  -0.832949  0.145391 -0.191181  5   2
# 2021-10-31  -1.256390 -0.200947 -0.641616  5   1

# %%
df1 = df.copy()
df1[df1 > 0] = -df1
df1
# Out:
#                     A         B         C  D   F
# 2021-01-31 -10.000000 -5.000000 -0.881847 -5 -10
# 2021-02-28  -1.574147 -1.236993 -0.341117 -5  -9
# 2021-03-31  -0.248623 -1.280873 -0.609198 -5  -8
# 2021-04-30  -1.143933 -2.295436 -0.847695 -5  -7
# 2021-05-31  -0.671510 -2.379146 -0.310086 -5  -6
# 2021-06-30  -0.543429 -0.926202 -1.063359 -5  -5
# 2021-07-31  -0.688580 -0.491351 -0.917668 -5  -4
# 2021-08-31  -2.076760 -1.336721 -2.234340 -5  -3
# 2021-09-30  -0.832949 -0.145391 -0.191181 -5  -2
# 2021-10-31  -1.256390 -0.200947 -0.641616 -5  -1

# %% [markdown]
# ## Missing data

# %%
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1
# Out:
#                     A         B         C  D   F   E
# 2021-01-31 -10.000000 -5.000000 -0.881847  5  10 NaN
# 2021-02-28  -1.574147  1.236993  0.341117  5   9 NaN
# 2021-03-31   0.248623  1.280873 -0.609198  5   8 NaN
# 2021-04-30   1.143933  2.295436 -0.847695  5   7 NaN

# %%
df1.loc[dates[0]:dates[1], 'E'] = 1
df1
# Out:
#                     A         B         C  D   F    E
# 2021-01-31 -10.000000 -5.000000 -0.881847  5  10  1.0
# 2021-02-28  -1.574147  1.236993  0.341117  5   9  1.0
# 2021-03-31   0.248623  1.280873 -0.609198  5   8  NaN
# 2021-04-30   1.143933  2.295436 -0.847695  5   7  NaN

# %%
df1.dropna(how='any')
# Out:
#                     A         B         C  D   F    E
# 2021-01-31 -10.000000 -5.000000 -0.881847  5  10  1.0
# 2021-02-28  -1.574147  1.236993  0.341117  5   9  1.0

# %%
df1.fillna(value=40)
# Out:
#                     A         B         C  D   F     E
# 2021-01-31 -10.000000 -5.000000 -0.881847  5  10   1.0
# 2021-02-28  -1.574147  1.236993  0.341117  5   9   1.0
# 2021-03-31   0.248623  1.280873 -0.609198  5   8  40.0
# 2021-04-30   1.143933  2.295436 -0.847695  5   7  40.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      F      E
# 2021-01-31  False  False  False  False  False  False
# 2021-02-28  False  False  False  False  False  False
# 2021-03-31  False  False  False  False  False   True
# 2021-04-30  False  False  False  False  False   True

# %% [markdown]
# ## Operations

# %%
df.mean()
# Out:
# A   -0.937751
# B   -0.352327
# C   -0.076047
# D    5.000000
# F    5.500000
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 2021-01-31   -0.176369
# 2021-02-28    2.800793
# 2021-03-31    2.784060
# 2021-04-30    2.918335
# 2021-05-31    1.796455
# 2021-06-30    2.289226
# 2021-07-31    1.655912
# 2021-08-31    2.194876
# 2021-09-30    1.224252
# 2021-10-31    0.780209
# Freq: M, dtype: float64

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 9, 10, 11, 1, 2], index=dates)
s
# Out:
# 2021-01-31     1.0
# 2021-02-28     3.0
# 2021-03-31     5.0
# 2021-04-30     NaN
# 2021-05-31     6.0
# 2021-06-30     9.0
# 2021-07-31    10.0
# 2021-08-31    11.0
# 2021-09-30     1.0
# 2021-10-31     2.0
# Freq: M, dtype: float64

# %%
s = s.shift(2)
s
# Out:
# 2021-01-31     NaN
# 2021-02-28     NaN
# 2021-03-31     1.0
# 2021-04-30     3.0
# 2021-05-31     5.0
# 2021-06-30     NaN
# 2021-07-31     6.0
# 2021-08-31     9.0
# 2021-09-30    10.0
# 2021-10-31    11.0
# Freq: M, dtype: float64

# %%
df
# Out:
#                     A         B         C  D   F
# 2021-01-31 -10.000000 -5.000000 -0.881847  5  10
# 2021-02-28  -1.574147  1.236993  0.341117  5   9
# 2021-03-31   0.248623  1.280873 -0.609198  5   8
# 2021-04-30   1.143933  2.295436 -0.847695  5   7
# 2021-05-31   0.671510 -2.379146 -0.310086  5   6
# 2021-06-30  -0.543429  0.926202  1.063359  5   5
# 2021-07-31   0.688580 -0.491351 -0.917668  5   4
# 2021-08-31   2.076760 -1.336721  2.234340  5   3
# 2021-09-30  -0.832949  0.145391 -0.191181  5   2
# 2021-10-31  -1.256390 -0.200947 -0.641616  5   1

# %%
# substract s from df column-wise
df.sub(s, axis='index')
# Out:
#                     A          B          C    D     F
# 2021-01-31        NaN        NaN        NaN  NaN   NaN
# 2021-02-28        NaN        NaN        NaN  NaN   NaN
# 2021-03-31  -0.751377   0.280873  -1.609198  4.0   7.0
# 2021-04-30  -1.856067  -0.704564  -3.847695  2.0   4.0
# 2021-05-31  -4.328490  -7.379146  -5.310086  0.0   1.0
# 2021-06-30        NaN        NaN        NaN  NaN   NaN
# 2021-07-31  -5.311420  -6.491351  -6.917668 -1.0  -2.0
# 2021-08-31  -6.923240 -10.336721  -6.765660 -4.0  -6.0
# 2021-09-30 -10.832949  -9.854609 -10.191181 -5.0  -8.0
# 2021-10-31 -12.256390 -11.200947 -11.641616 -6.0 -10.0

# %%
# apply function to each column
df.apply(np.cumsum)
# Out:
#                     A         B         C   D   F
# 2021-01-31 -10.000000 -5.000000 -0.881847   5  10
# 2021-02-28 -11.574147 -3.763007 -0.540730  10  19
# 2021-03-31 -11.325524 -2.482133 -1.149928  15  27
# 2021-04-30 -10.181591 -0.186697 -1.997623  20  34
# 2021-05-31  -9.510082 -2.565844 -2.307709  25  40
# 2021-06-30 -10.053511 -1.639641 -1.244350  30  45
# 2021-07-31  -9.364931 -2.130992 -2.162019  35  49
# 2021-08-31  -7.288171 -3.467713  0.072322  40  52
# 2021-09-30  -8.121120 -3.322322 -0.118859  45  54
# 2021-10-31  -9.377510 -3.523270 -0.760475  50  55

# %% [markdown]
# ## Apply

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    12.076760
# B     7.295436
# C     3.152009
# D     0.000000
# F     9.000000
# dtype: float64

# %%
df.apply(np.mean)
# Out:
# A   -0.937751
# B   -0.352327
# C   -0.076047
# D    5.000000
# F    5.500000
# dtype: float64

# %%
df.apply(lambda x: x.mean())
# Out:
# A   -0.937751
# B   -0.352327
# C   -0.076047
# D    5.000000
# F    5.500000
# dtype: float64

# %% [markdown]
# ## Histogramming

# %%
s = pd.Series(np.random.randint(0, 7, size=10))
s
# Out:
# 0    0
# 1    5
# 2    6
# 3    4
# 4    3
# 5    2
# 6    3
# 7    3
# 8    6
# 9    3
# dtype: int64

# %%
s.shape
# Out:
# (10,)

# %%
s.value_counts()
# Out:
# 3    4
# 6    2
# 0    1
# 5    1
# 4    1
# 2    1
# dtype: int64

# %% [markdown]
# ## String methods

# %%
s = pd.Series(['A', 'B', 'C', 'David', 'James', np.nan, 'dog', 'cat'])

# %%
s.str.upper()
s.str.translate(str.maketrans('a', 'z'))
# Out:
# 0        A
# 1        B
# 2        C
# 3    Dzvid
# 4    Jzmes
# 5      NaN
# 6      dog
# 7      czt
# dtype: object

# %% [markdown]
# ## Merge

# %%
df = pd.DataFrame(np.random.randn(10, 4))
df
# Out:
#           0         1         2         3
# 0 -0.230976 -0.916066  1.017757  0.944446
# 1 -1.036984  1.014068 -1.670978 -1.125737
# 2  1.185012  1.590583 -1.287831  0.631143
# 3 -0.199958 -1.097671  1.479371 -0.532749
# 4 -0.552346 -0.155906  0.685295  0.847718
# 5 -0.634552 -0.583472 -0.133149  0.188843
# 6  1.805991 -0.893611  1.255020  0.361699
# 7  0.678414 -0.922099 -0.459632 -0.527460
# 8  0.276418  0.286328  0.082690  0.870314
# 9  1.146359 -0.318149 -0.953050  1.183766

# %%
pieces = [df[:3], df[3:7], df[7:]]
pieces
# Out:
# [          0         1         2         3
#  0 -0.230976 -0.916066  1.017757  0.944446
#  1 -1.036984  1.014068 -1.670978 -1.125737
#  2  1.185012  1.590583 -1.287831  0.631143,
#            0         1         2         3
#  3 -0.199958 -1.097671  1.479371 -0.532749
#  4 -0.552346 -0.155906  0.685295  0.847718
#  5 -0.634552 -0.583472 -0.133149  0.188843
#  6  1.805991 -0.893611  1.255020  0.361699,
#            0         1         2         3
#  7  0.678414 -0.922099 -0.459632 -0.527460
#  8  0.276418  0.286328  0.082690  0.870314
#  9  1.146359 -0.318149 -0.953050  1.183766]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0 -0.230976 -0.916066  1.017757  0.944446
# 1 -1.036984  1.014068 -1.670978 -1.125737
# 2  1.185012  1.590583 -1.287831  0.631143
# 3 -0.199958 -1.097671  1.479371 -0.532749
# 4 -0.552346 -0.155906  0.685295  0.847718
# 5 -0.634552 -0.583472 -0.133149  0.188843
# 6  1.805991 -0.893611  1.255020  0.361699
# 7  0.678414 -0.922099 -0.459632 -0.527460
# 8  0.276418  0.286328  0.082690  0.870314
# 9  1.146359 -0.318149 -0.953050  1.183766

# %%
left = pd.DataFrame({'key': ['david', 'james'], 'lval': [1, 2]})
right = pd.DataFrame({'key': ['david', 'james'], 'rval': [4, 5]})

# %%
left
# Out:
#      key  lval
# 0  david     1
# 1  james     2

# %%
right
# Out:
#      key  rval
# 0  david     4
# 1  james     5

# %%
pd.merge(left, right, on="key")
# Out:
#      key  lval  rval
# 0  david     1     4
# 1  james     2     5

# %% [markdown]
# ## Grouping

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)
df
# Out:
#      A      B         C         D
# 0  foo    one -0.791797  0.942542
# 1  bar    one -0.801481 -1.585848
# 2  foo    two  0.211294 -1.009985
# 3  bar  three  0.270672 -1.429581
# 4  foo    two -0.243893 -0.760698
# 5  bar    two  0.266679  0.324618
# 6  foo    one -0.652750  0.918721
# 7  foo  three -1.127557 -0.000866

# %%
df.groupby('A').sum()
# Out:
#             C         D
# A
# bar -0.264131 -2.690811
# foo -2.604703  0.089715

# %%
df.groupby(['A', 'B']).mean()
# Out:
#                   C         D
# A   B
# bar one   -0.801481 -1.585848
#     three  0.270672 -1.429581
#     two    0.266679  0.324618
# foo one   -0.722273  0.930632
#     three -1.127557 -0.000866
#     two   -0.016300 -0.885341

# %% [markdown]
# ## Reshaping

# %%
tuples = list(
    zip(
        *[
            ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
            ["one", "two", "one", "two", "one", "two", "one", "two"],
        ]
    )
)
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=['first', 'second'])
index
# Out:
# MultiIndex([('bar', 'one'),
#             ('bar', 'two'),
#             ('baz', 'one'),
#             ('baz', 'two'),
#             ('foo', 'one'),
#             ('foo', 'two'),
#             ('qux', 'one'),
#             ('qux', 'two')],
#            names=['first', 'second'])

# %%
df = pd.DataFrame(
    np.random.randn(8, 2), index=index, columns=['A', 'B']
)
df
# Out:
#                      A         B
# first second
# bar   one     0.902541  0.279577
#       two     0.122636  1.149279
# baz   one     0.132465  0.566013
#       two    -1.767405 -0.338247
# foo   one     2.179197 -1.513662
#       two    -0.007991  0.154504
# qux   one     0.325273  0.270421
#       two    -1.439089 -1.343252

# %%
df2 = df[:4]
df2
# Out:
#                      A         B
# first second
# bar   one     0.902541  0.279577
#       two     0.122636  1.149279
# baz   one     0.132465  0.566013
#       two    -1.767405 -0.338247

# %%
stacked = df2.stack()
stacked
# Out:
# first  second
# bar    one     A    0.902541
#                B    0.279577
#        two     A    0.122636
#                B    1.149279
# baz    one     A    0.132465
#                B    0.566013
#        two     A   -1.767405
#                B   -0.338247
# dtype: float64

# %%
type(stacked)
# Out:
# pandas.core.series.Series

# %%
stacked.index
# Out:
# MultiIndex([('bar', 'one', 'A'),
#             ('bar', 'one', 'B'),
#             ('bar', 'two', 'A'),
#             ('bar', 'two', 'B'),
#             ('baz', 'one', 'A'),
#             ('baz', 'one', 'B'),
#             ('baz', 'two', 'A'),
#             ('baz', 'two', 'B')],
#            names=['first', 'second', None])

# %%
stacked.unstack()
# Out:
#                      A         B
# first second
# bar   one     0.902541  0.279577
#       two     0.122636  1.149279
# baz   one     0.132465  0.566013
#       two    -1.767405 -0.338247

# %%
stacked.unstack(1)
# Out:
# second        one       two
# first
# bar   A  0.902541  0.122636
#       B  0.279577  1.149279
# baz   A  0.132465 -1.767405
#       B  0.566013 -0.338247

# %%
stacked.unstack(0)
# Out:
# first          bar       baz
# second
# one    A  0.902541  0.132465
#        B  0.279577  0.566013
# two    A  0.122636 -1.767405
#        B  1.149279 -0.338247

# %%
df = pd.DataFrame(
    np.random.randn(8, 2), columns=['A', 'B']
)
df['C'] = ['david'] * 4  + ['james'] * 4
df['D'] = [1, 2, 3, 4] * 2
df
# Out:
#           A         B      C  D
# 0 -0.762284  1.065593  david  1
# 1  0.125169 -0.438655  david  2
# 2 -1.593319  0.808080  david  3
# 3  0.443367 -0.012408  david  4
# 4  0.247526  0.231399  james  1
# 5 -0.885227  0.642852  james  2
# 6  0.955381  1.393771  james  3
# 7 -0.371680  0.152552  james  4

# %%
df_wide = df.pivot(columns='C', index='D', values='A')
df_wide
# Out:
# C     david     james
# D
# 1 -0.762284  0.247526
# 2  0.125169 -0.885227
# 3 -1.593319  0.955381
# 4  0.443367 -0.371680

# %%
pd.pivot_table(df, values='A', index='D', columns='C')
# Out:
# C     david     james
# D
# 1 -0.762284  0.247526
# 2  0.125169 -0.885227
# 3 -1.593319  0.955381
# 4  0.443367 -0.371680

# %%
pd.pivot_table(df, values='A', index='D', columns=['C'])
# Out:
# C     david     james
# D
# 1 -0.762284  0.247526
# 2  0.125169 -0.885227
# 3 -1.593319  0.955381
# 4  0.443367 -0.371680

# %%
df_wide.unstack()
# Out:
# C      D
# david  1   -0.762284
#        2    0.125169
#        3   -1.593319
#        4    0.443367
# james  1    0.247526
#        2   -0.885227
#        3    0.955381
#        4   -0.371680
# dtype: float64

# %%
df_wide.melt(value_name='A')
# Out:
#        C         A
# 0  david -0.762284
# 1  david  0.125169
# 2  david -1.593319
# 3  david  0.443367
# 4  james  0.247526
# 5  james -0.885227
# 6  james  0.955381
# 7  james -0.371680

# %% [markdown]
# ## Categoricals

# %%
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df['grade'] = df['raw_grade'].astype('category')
df['grade']
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
df['grade'].cat.categories = ['very good', 'good', 'very bad']
df.grade
# Out:
# 0    very good
# 1         good
# 2         good
# 3    very good
# 4    very good
# 5     very bad
# Name: grade, dtype: category
# Categories (3, object): ['very good', 'good', 'very bad']

# %%
df.sort_values(by='grade')
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good
# 1   2         b       good
# 2   3         b       good
# 5   6         e   very bad

# %%
df.groupby('grade').count()
# Out:
#            id  raw_grade
# grade
# very good   3          3
# good        2          2
# very bad    1          1

# %%
type(df.groupby('grade').size())
# Out:
# pandas.core.series.Series
